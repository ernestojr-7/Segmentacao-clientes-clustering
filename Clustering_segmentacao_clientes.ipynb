# %% [markdown]
# <a href="https://colab.research.google.com/github/ernestojr-7/Segmentacao-clientes-clustering/blob/main/Clustering_segmentacao_clientes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %% [markdown]
# #Análise exploratória dos dados

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/BancoDeDados.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116581 entries, 0 to 116580
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   amostra               116581 non-null  int64
#  1   id_cliente            116581 non-null  object
#  2   id_unico_cliente      116581 non-null  object
#  3   item_id               116581 non-null  int64
#  4   cep_cliente           116581 non-null  int64
#  5   cidade_cliente        116581 non-null  object
#  6   estado_cliente        116581 non-null  object
#  7   id_pedido             116581 non-null  object
#  8   status_pedido         116581 non-null  object
#  9   horario_pedido        116581 non-null  object
#  10  pedido_aprovado       116567 non-null  object
#  11  pedido_entregador     115368 non-null  object
#  12  pedido_entregue       114066 non-null  object
#  13  data_estimada         116581 non-null  object
#  14  id_vendedor           116581 non-null  object
#  15  preco                 116581 non-null  float64
#  16  frete                 116581 non-null  float64
#  17  pagamento_sequencial  116581 non-null  int64
#  18  pagamento_tipo        116581 non-null  object
#  19  pagamento_prestacoes  116581 non-null  int64
#  20  pagamento_valor       116581 non-null  float64
#  21  review                116581 non-null  int64
#  22  categoria             116581 non-null  object
#  23  categoria_ingles      116581 non-null  object
#  24  cep_vendedor          116581 non-null  int64
#  25  cidade_vendedor       116581 non-null  object
#  26  estado_vendedor       116581 non-null  object
# dtypes: float64(3), int64(7), object(17)
# memory usage: 24.0+ MB

# %%
df.describe()
# Out:
#              amostra        item_id  ...         review   cep_vendedor
# count  116581.000000  116581.000000  ...  116581.000000  116581.000000
# mean    58290.000000       1.196953  ...       4.017507   24504.889030
# std     33654.180203       0.701350  ...       1.397886   27625.157426
# min         0.000000       1.000000  ...       1.000000    1001.000000
# 25%     29145.000000       1.000000  ...       4.000000    6429.000000
# 50%     58290.000000       1.000000  ...       5.000000   13690.000000
# 75%     87435.000000       1.000000  ...       5.000000   28495.000000
# max    116580.000000      21.000000  ...       5.000000   99730.000000
#
# [8 rows x 10 columns]

# %%
df.head()
# Out:
#    amostra                        id_cliente  ...  cidade_vendedor  estado_vendedor
# 0        0  06b8999e2fba1a1fbc88172c00ba8bc7  ...  itaquaquecetuba               SP
# 1        1  8912fc0c3bbf1e2fbf35819e21706718  ...  itaquaquecetuba               SP
# 2        2  8912fc0c3bbf1e2fbf35819e21706718  ...  itaquaquecetuba               SP
# 3        3  f0ac8e5a239118859b1734e1087cbb1f  ...  itaquaquecetuba               SP
# 4        4  6bc8d08963a135220ed6c6d098831f84  ...  itaquaquecetuba               SP
#
# [5 rows x 27 columns]

# %%
def plot_percent(estado, dados):
    plt.figure(figsize=(20,8))  
    g = sns.countplot(x= estado,data=dados,orient='h')
    g.set_ylabel('Contagem',fontsize=17)    
    sizes = []
    
    for p in g.patches:
        # print(f'valor de P: {p}')
        height = p.get_height()
        sizes.append(height)
        g.text(p.get_x() + p.get_width()/1.6,
              height+200,
              f'{height/116581*100:1.2f}%',
              ha ='center',va='bottom',fontsize=12)
        
    g.set_ylim(0,max(sizes)*1.1)

# %%
plot_percent('estado_cliente',df)

# %%
plot_percent('estado_vendedor',df)

# %%
plot_percent('pagamento_tipo',df)

# %%
sudeste = ['SP', 'RJ', 'ES','MG']
nordeste= ['MA', 'PI', 'CE', 'RN', 'PE', 'PB', 'SE', 'AL', 'BA']
norte =  ['AM', 'RR', 'AP', 'PA', 'TO', 'RO', 'AC']
centro_oeste = ['MT', 'GO', 'MS' ,'DF' ]
sul = ['SC', 'RS', 'PR']

df.loc[df['estado_cliente'].isin(sudeste), 'Regiao'] = 'Southeast'
df.loc[df['estado_cliente'].isin(nordeste), 'Regiao'] = 'Northeast'
df.loc[df['estado_cliente'].isin(norte), 'Regiao'] = 'North'
df.loc[df['estado_cliente'].isin(centro_oeste), 'Regiao'] = 'Midwest'
df.loc[df['estado_cliente'].isin(sul), 'Regiao'] = 'South'

# %%
def cross_heatmap(df, cols, normalize=False, values=None, aggfunc=None):
    temp = cols
    cm = sns.light_palette("blue", as_cmap=True)
    return pd.crosstab(df[temp[0]], df[temp[1]],
                       normalize=normalize, values=values, aggfunc=aggfunc).style.background_gradient(cmap = cm)

# %%
cross_heatmap(df, ['estado_vendedor', 'Regiao'], values=df['frete'], aggfunc='mean')
# Out:
# <style type="text/css">
# #T_bd5a2_row0_col0, #T_bd5a2_row0_col1, #T_bd5a2_row0_col2, #T_bd5a2_row0_col3, #T_bd5a2_row1_col0, #T_bd5a2_row1_col1, #T_bd5a2_row1_col3, #T_bd5a2_row11_col0, #T_bd5a2_row11_col1, #T_bd5a2_row11_col2, #T_bd5a2_row12_col3, #T_bd5a2_row14_col0, #T_bd5a2_row14_col1, #T_bd5a2_row18_col0, #T_bd5a2_row18_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_bd5a2_row0_col4 {
#   background-color: #8484f8;
#   color: #f1f1f1;
# }
# #T_bd5a2_row1_col2 {
#   background-color: #aeaef6;
#   color: #000000;
# }
# #T_bd5a2_row1_col4, #T_bd5a2_row9_col0 {
#   background-color: #b4b4f6;
#   color: #000000;
# }
# #T_bd5a2_row2_col0, #T_bd5a2_row8_col3, #T_bd5a2_row13_col4, #T_bd5a2_row22_col2 {
#   background-color: #a3a3f7;
#   color: #f1f1f1;
# }
# #T_bd5a2_row2_col1, #T_bd5a2_row8_col2 {
#   background-color: #9292f8;
#   color: #f1f1f1;
# }
# #T_bd5a2_row2_col2 {
#   background-color: #c9c9f5;
#   color: #000000;
# }
# #T_bd5a2_row2_col3 {
#   background-color: #5656fb;
#   color: #f1f1f1;
# }
# #T_bd5a2_row2_col4 {
#   background-color: #7f7ff9;
#   color: #f1f1f1;
# }
# #T_bd5a2_row3_col0, #T_bd5a2_row3_col1, #T_bd5a2_row3_col3, #T_bd5a2_row12_col4, #T_bd5a2_row18_col2 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_bd5a2_row3_col2 {
#   background-color: #a7a7f7;
#   color: #000000;
# }
# #T_bd5a2_row3_col4 {
#   background-color: #2929fd;
#   color: #f1f1f1;
# }
# #T_bd5a2_row4_col0, #T_bd5a2_row12_col1, #T_bd5a2_row17_col2, #T_bd5a2_row19_col3, #T_bd5a2_row22_col4 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# #T_bd5a2_row4_col1 {
#   background-color: #6565fa;
#   color: #f1f1f1;
# }
# #T_bd5a2_row4_col2, #T_bd5a2_row4_col3, #T_bd5a2_row19_col4 {
#   background-color: #b1b1f6;
#   color: #000000;
# }
# #T_bd5a2_row4_col4, #T_bd5a2_row21_col3 {
#   background-color: #d9d9f4;
#   color: #000000;
# }
# #T_bd5a2_row5_col0 {
#   background-color: #8383f8;
#   color: #f1f1f1;
# }
# #T_bd5a2_row5_col1 {
#   background-color: #5f5ffa;
#   color: #f1f1f1;
# }
# #T_bd5a2_row5_col2, #T_bd5a2_row10_col2 {
#   background-color: #7e7ef9;
#   color: #f1f1f1;
# }
# #T_bd5a2_row5_col3 {
#   background-color: #5454fb;
#   color: #f1f1f1;
# }
# #T_bd5a2_row5_col4, #T_bd5a2_row13_col0 {
#   background-color: #9e9ef7;
#   color: #f1f1f1;
# }
# #T_bd5a2_row6_col0 {
#   background-color: #eaeaf3;
#   color: #000000;
# }
# #T_bd5a2_row6_col1, #T_bd5a2_row13_col2 {
#   background-color: #dcdcf4;
#   color: #000000;
# }
# #T_bd5a2_row6_col2 {
#   background-color: #9696f7;
#   color: #f1f1f1;
# }
# #T_bd5a2_row6_col3 {
#   background-color: #9999f7;
#   color: #f1f1f1;
# }
# #T_bd5a2_row6_col4, #T_bd5a2_row22_col1 {
#   background-color: #bebef5;
#   color: #000000;
# }
# #T_bd5a2_row7_col0, #T_bd5a2_row8_col0 {
#   background-color: #b0b0f6;
#   color: #000000;
# }
# #T_bd5a2_row7_col1 {
#   background-color: #d3d3f4;
#   color: #000000;
# }
# #T_bd5a2_row7_col2, #T_bd5a2_row10_col1 {
#   background-color: #d8d8f4;
#   color: #000000;
# }
# #T_bd5a2_row7_col3 {
#   background-color: #3f3ffc;
#   color: #f1f1f1;
# }
# #T_bd5a2_row7_col4 {
#   background-color: #8b8bf8;
#   color: #f1f1f1;
# }
# #T_bd5a2_row8_col1, #T_bd5a2_row13_col1 {
#   background-color: #a2a2f7;
#   color: #f1f1f1;
# }
# #T_bd5a2_row8_col4 {
#   background-color: #cecef4;
#   color: #000000;
# }
# #T_bd5a2_row9_col1, #T_bd5a2_row15_col3 {
#   background-color: #efeff3;
#   color: #000000;
# }
# #T_bd5a2_row9_col2 {
#   background-color: #a9a9f6;
#   color: #000000;
# }
# #T_bd5a2_row9_col3 {
#   background-color: #bdbdf5;
#   color: #000000;
# }
# #T_bd5a2_row9_col4 {
#   background-color: #ccccf5;
#   color: #000000;
# }
# #T_bd5a2_row10_col0 {
#   background-color: #bfbff5;
#   color: #000000;
# }
# #T_bd5a2_row10_col3 {
#   background-color: #7a7af9;
#   color: #f1f1f1;
# }
# #T_bd5a2_row10_col4 {
#   background-color: #7c7cf9;
#   color: #f1f1f1;
# }
# #T_bd5a2_row11_col3 {
#   background-color: #7272f9;
#   color: #f1f1f1;
# }
# #T_bd5a2_row11_col4 {
#   background-color: #e9e9f3;
#   color: #000000;
# }
# #T_bd5a2_row12_col0 {
#   background-color: #7b7bf9;
#   color: #f1f1f1;
# }
# #T_bd5a2_row12_col2 {
#   background-color: #d7d7f4;
#   color: #000000;
# }
# #T_bd5a2_row13_col3 {
#   background-color: #0a0afe;
#   color: #f1f1f1;
# }
# #T_bd5a2_row14_col2 {
#   background-color: #b6b6f6;
#   color: #000000;
# }
# #T_bd5a2_row14_col3 {
#   background-color: #2121fd;
#   color: #f1f1f1;
# }
# #T_bd5a2_row14_col4, #T_bd5a2_row20_col2 {
#   background-color: #4040fc;
#   color: #f1f1f1;
# }
# #T_bd5a2_row15_col0, #T_bd5a2_row15_col1 {
#   background-color: #9393f8;
#   color: #f1f1f1;
# }
# #T_bd5a2_row15_col2 {
#   background-color: #6161fa;
#   color: #f1f1f1;
# }
# #T_bd5a2_row15_col4 {
#   background-color: #d0d0f4;
#   color: #000000;
# }
# #T_bd5a2_row16_col0 {
#   background-color: #cecef5;
#   color: #000000;
# }
# #T_bd5a2_row16_col1 {
#   background-color: #adadf6;
#   color: #000000;
# }
# #T_bd5a2_row16_col2 {
#   background-color: #9797f7;
#   color: #f1f1f1;
# }
# #T_bd5a2_row16_col3, #T_bd5a2_row21_col1 {
#   background-color: #dedef4;
#   color: #000000;
# }
# #T_bd5a2_row16_col4 {
#   background-color: #ebebf3;
#   color: #000000;
# }
# #T_bd5a2_row17_col0 {
#   background-color: #c4c4f5;
#   color: #000000;
# }
# #T_bd5a2_row17_col1 {
#   background-color: #ddddf4;
#   color: #000000;
# }
# #T_bd5a2_row17_col3 {
#   background-color: #3535fc;
#   color: #f1f1f1;
# }
# #T_bd5a2_row17_col4 {
#   background-color: #6969fa;
#   color: #f1f1f1;
# }
# #T_bd5a2_row18_col3 {
#   background-color: #3b3bfc;
#   color: #f1f1f1;
# }
# #T_bd5a2_row18_col4 {
#   background-color: #1919fe;
#   color: #f1f1f1;
# }
# #T_bd5a2_row19_col0 {
#   background-color: #9494f7;
#   color: #f1f1f1;
# }
# #T_bd5a2_row19_col1 {
#   background-color: #9d9df7;
#   color: #f1f1f1;
# }
# #T_bd5a2_row19_col2 {
#   background-color: #4747fb;
#   color: #f1f1f1;
# }
# #T_bd5a2_row20_col0 {
#   background-color: #8888f8;
#   color: #f1f1f1;
# }
# #T_bd5a2_row20_col1, #T_bd5a2_row21_col4 {
#   background-color: #8080f8;
#   color: #f1f1f1;
# }
# #T_bd5a2_row20_col3 {
#   background-color: #e0e0f4;
#   color: #000000;
# }
# #T_bd5a2_row20_col4 {
#   background-color: #babaf6;
#   color: #000000;
# }
# #T_bd5a2_row21_col0 {
#   background-color: #8686f8;
#   color: #f1f1f1;
# }
# #T_bd5a2_row21_col2 {
#   background-color: #7878f9;
#   color: #f1f1f1;
# }
# #T_bd5a2_row22_col0 {
#   background-color: #cacaf5;
#   color: #000000;
# }
# #T_bd5a2_row22_col3 {
#   background-color: #dfdff4;
#   color: #000000;
# }
# </style>
# <table id="T_bd5a2_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Regiao</th>
#       <th class="col_heading level0 col0" >Midwest</th>
#       <th class="col_heading level0 col1" >North</th>
#       <th class="col_heading level0 col2" >Northeast</th>
#       <th class="col_heading level0 col3" >South</th>
#       <th class="col_heading level0 col4" >Southeast</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >estado_vendedor</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd5a2_level0_row0" class="row_heading level0 row0" >AC</th>
#       <td id="T_bd5a2_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_bd5a2_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_bd5a2_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_bd5a2_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_bd5a2_row0_col4" class="data row0 col4" >32.840000</td>
#     </tr>
#     <tr>
#       <th id="T_bd5a2_level0_row1" class="row_heading level0 row1" >AM</th>
#       <td id="T_bd5a2_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_bd5a2_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_bd5a2_row1_col2" class="data row1 col2" >28.255000</td>
#       <td id="T_bd5a2_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_bd5a2_row1_col4" class="data row1 col4" >25.290000</td>
#     </tr>
#     <tr>
#       <th id="T_bd5a2_level0_row2" class="row_heading level0 row2" >BA</th>
#       <td id="T_bd5a2_row2_col0" class="data row2 col0" >29.977381</td>
#       <td id="T_bd5a2_row2_col1" class="data row2 col1" >46.290476</td>
#       <td id="T_bd5a2_row2_col2" class="data row2 col2" >22.736355</td>
#       <td id="T_bd5a2_row2_col3" class="data row2 col3" >39.643671</td>

# %% [markdown]
# > ## Recência (R)
# > #### Há quantos dias foi a última compra desse cliente?
#
# > ## Frequência (F)
# > #### Quantas compras esse cliente já fez na sua empresa, desde que se cadastrou?
#
# > ## Monetaridade (M)
# > #### Quanto esse cliente já gastou em dinheiro na sua empresa?

# %%
df_olist = df[['id_unico_cliente','id_cliente','horario_pedido','item_id','preco']]
df_olist.head()
# Out:
#                    id_unico_cliente  ...   preco
# 0  861eff4711a542e4b93843c6dd7febb0  ...  124.99
# 1  9eae34bbd3a474ec5d07949ca7de67c0  ...  112.99
# 2  9eae34bbd3a474ec5d07949ca7de67c0  ...  112.99
# 3  3c799d181c34d51f6d44bbbc563024db  ...  124.99
# 4  23397e992b09769faf5e66f9e171a241  ...  106.99
#
# [5 rows x 5 columns]

# %%
df_compra = df.groupby('id_unico_cliente').horario_pedido.max().reset_index()
df_compra.columns = ['id_unico_cliente','DataMaxCompra']
df_compra['DataMaxCompra'] = pd.to_datetime(df_compra['DataMaxCompra'])
df_compra.head()
# Out:
#                    id_unico_cliente       DataMaxCompra
# 0  0000366f3b9a7992bf8c76cfdf3221e2 2018-05-10 10:56:27
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f 2018-05-07 11:11:27
# 2  0000f46a3911fa3c0805444483337064 2017-03-10 21:05:03
# 3  0000f6ccb0745a6a4b88665a16c9f078 2017-10-12 20:29:41
# 4  0004aac84e0df4da2b147fca70cf8255 2017-11-14 19:45:42

# %%
df_compra['Recencia'] = (df_compra['DataMaxCompra'].max() - df_compra['DataMaxCompra']).dt.days
df_compra.head()
# Out:
#                    id_unico_cliente       DataMaxCompra  Recencia
# 0  0000366f3b9a7992bf8c76cfdf3221e2 2018-05-10 10:56:27       115
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f 2018-05-07 11:11:27       118
# 2  0000f46a3911fa3c0805444483337064 2017-03-10 21:05:03       541
# 3  0000f6ccb0745a6a4b88665a16c9f078 2017-10-12 20:29:41       325
# 4  0004aac84e0df4da2b147fca70cf8255 2017-11-14 19:45:42       292

# %%
df_usuario = pd.merge(df_olist,df_compra[['id_unico_cliente','Recencia']], on='id_unico_cliente')
df_usuario.head()
# Out:
#                    id_unico_cliente  ... Recencia
# 0  861eff4711a542e4b93843c6dd7febb0  ...      474
# 1  9eae34bbd3a474ec5d07949ca7de67c0  ...      298
# 2  9eae34bbd3a474ec5d07949ca7de67c0  ...      298
# 3  3c799d181c34d51f6d44bbbc563024db  ...      483
# 4  23397e992b09769faf5e66f9e171a241  ...      211
#
# [5 rows x 6 columns]

# %% [markdown]
# #Encontrando quantidade se clusters ideal

# %%
def calcular_wcss(data):
    wcss = []
    for k in range(1,10):
        kmeans = KMeans(n_clusters = k)
        kmeans.fit(X=data)
        data['Clusters']=kmeans.labels_
        wcss.append(kmeans.inertia_)
    return wcss

# %% [markdown]
# > Algo a se perguntar, será que a inércia é tão boa assim? O que acontece é que a inércia é uma métrica que funciona bem em clusters que são redondos, mas ela acaba sendo meio ruim se algum dos clusters tem formato irregular, pois se algum cluster tem formato irregular, é possível que alguns dos pontos estejam muito longe do central e de outros muito perto, então é como se você tivesse uma variância muito grande.

# %% [markdown]
# > Agora precisamos usar o Método Cotovelo, a ideia é rodar o KMeans para várias quantidades diferentes de clusters e dizer qual dessas quantidades é o número ótimo de clusters. Usando a "regra do cotovelo", identificamos que a partir de 4 clusters teremos bons resultados. Será usado 5 apenas para garantir.
#
# > O que geralmente acontece ao aumentar a quantidade de clusters no KMeans é que as diferenças entre clusters se tornam muito pequenas, e as diferenças das observações intra-clusters vão aumentando. Então é preciso achar um equilíbrio em que as observações que formam cada agrupamento sejam o mais homogêneas possível e que os agrupamentos formados sejam o mais diferentes um dos outros.

# %%
from sklearn.cluster import KMeans

df_recencia = df_usuario[['Recencia']]
df_recencia.head()
# Out:
#    Recencia
# 0       474
# 1       298
# 2       298
# 3       483
# 4       211

# %%
soma_quadrados = calcular_wcss(df_recencia)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plt.figure(figsize=(10,5))
plt.plot(soma_quadrados)
plt.xlabel('Número de clusters')
plt.show()

# %% [markdown]
# > Mas como podemos identificar se o melhor número de clusters é 3, 4 ou 5? Existe uma solução matemática! Primeiramente, definimos uma reta ligando o primeiro ponto (cluster 1) ao último ponto (cluster 9). Então, calculamos a distância de cada ponto até a reta usando a seguinte equação:

# %% [markdown]
# ![](https://miro.medium.com/max/2775/1*9J7Wnh5L0eIcHXBeWlzvNA.png)

# %% [markdown]
# > Neste caso, P0 é o ponto do cluster 1 e P1 o ponto do cluster 9. O par (x,y) representa as coordenadas de qualquer ponto que a gente queira calcular a distância. Calculando todas as distância, conseguimos determinar o ponto ideal!

# %%
import math
def numero_otimo_clusters(wcss):
    x1, y1 = 2,wcss[1]
    x2, y2 = 10,wcss[len(wcss)-1]
    
    distancia = []
    for i in range(len(wcss)-1):
        x = i+2
        y = wcss[i+1]
        numerador = abs((y2 - y1)*x- (x2 - x1)*y + x2*y1 - y2*x1)
        denominador = math.sqrt((y2 - y1)**2 + (x2 - x1)**2)
        distancia.append(numerador/denominador)
    return distancia.index(max(distancia)) + 2

# %%
n = numero_otimo_clusters(soma_quadrados)
n
# Out:
# 4

# %% [markdown]
# #Clusterizando a Recência

# %%
kmeans=KMeans(n_clusters=4)
df_usuario['RecenciaCluster'] = kmeans.fit_predict(df_recencia)
df_usuario.head()
# Out:
#                    id_unico_cliente  ... RecenciaCluster
# 0  861eff4711a542e4b93843c6dd7febb0  ...               1
# 1  9eae34bbd3a474ec5d07949ca7de67c0  ...               3
# 2  9eae34bbd3a474ec5d07949ca7de67c0  ...               3
# 3  3c799d181c34d51f6d44bbbc563024db  ...               1
# 4  23397e992b09769faf5e66f9e171a241  ...               0
#
# [5 rows x 7 columns]

# %%
agrupado_por_cluster = df_usuario.groupby('RecenciaCluster')['Recencia'].mean().reset_index()
agrupado_por_cluster.head()
# Out:
#    RecenciaCluster    Recencia
# 0                0  187.076277
# 1                1  489.070832
# 2                2   66.405850
# 3                3  318.687376

# %%
agrupado_por_cluster_ordenado = agrupado_por_cluster.sort_values(by='Recencia',ascending=False).reset_index(drop=True)
agrupado_por_cluster_ordenado.head()
# Out:
#    RecenciaCluster    Recencia
# 0                1  489.070832
# 1                3  318.687376
# 2                0  187.076277
# 3                2   66.405850

# %%
agrupado_por_cluster_ordenado['index'] = agrupado_por_cluster_ordenado.index
agrupado_por_cluster_ordenado.head()
# Out:
#    RecenciaCluster    Recencia  index
# 0                1  489.070832      0
# 1                3  318.687376      1
# 2                0  187.076277      2
# 3                2   66.405850      3

# %%
juntando_cluster = pd.merge(df_usuario, agrupado_por_cluster_ordenado[['RecenciaCluster','index']],on='RecenciaCluster')
juntando_cluster.head()
# Out:
#                    id_unico_cliente  ... index
# 0  861eff4711a542e4b93843c6dd7febb0  ...     2
# 1  3c799d181c34d51f6d44bbbc563024db  ...     2
# 2  567ab47ca4deb92d46dbf54dce07d0a7  ...     2
# 3  f40ab89b622248b7ca125af4b486b887  ...     2
# 4  749943913a9851a39c9baf51877fbab6  ...     2
#
# [5 rows x 8 columns]

# %%
removendo_dandos = juntando_cluster.drop(['RecenciaCluster'],axis=1)
removendo_dandos.head()
# Out:
#                    id_unico_cliente  ... index
# 0  861eff4711a542e4b93843c6dd7febb0  ...     2
# 1  3c799d181c34d51f6d44bbbc563024db  ...     2
# 2  567ab47ca4deb92d46dbf54dce07d0a7  ...     2
# 3  f40ab89b622248b7ca125af4b486b887  ...     2
# 4  749943913a9851a39c9baf51877fbab6  ...     2
#
# [5 rows x 7 columns]

# %%
df_final = removendo_dandos.rename(columns={'index':'RecenciaCluster'})
df_final.head()
# Out:
#                    id_unico_cliente  ... RecenciaCluster
# 0  861eff4711a542e4b93843c6dd7febb0  ...               2
# 1  3c799d181c34d51f6d44bbbc563024db  ...               2
# 2  567ab47ca4deb92d46dbf54dce07d0a7  ...               2
# 3  f40ab89b622248b7ca125af4b486b887  ...               2
# 4  749943913a9851a39c9baf51877fbab6  ...               2
#
# [5 rows x 7 columns]

# %%
df_usuario.head()
# Out:
#                    id_unico_cliente  ... RecenciaCluster
# 0  861eff4711a542e4b93843c6dd7febb0  ...               0
# 1  3c799d181c34d51f6d44bbbc563024db  ...               0
# 2  567ab47ca4deb92d46dbf54dce07d0a7  ...               0
# 3  f40ab89b622248b7ca125af4b486b887  ...               0
# 4  749943913a9851a39c9baf51877fbab6  ...               0
#
# [5 rows x 7 columns]

# %%
df_usuario.head()
# Out:
#                    id_unico_cliente  ... RecenciaCluster
# 0  861eff4711a542e4b93843c6dd7febb0  ...               0
# 1  3c799d181c34d51f6d44bbbc563024db  ...               0
# 2  567ab47ca4deb92d46dbf54dce07d0a7  ...               0
# 3  f40ab89b622248b7ca125af4b486b887  ...               0
# 4  749943913a9851a39c9baf51877fbab6  ...               0
#
# [5 rows x 7 columns]

# %%
def ordenador_cluster(cluster_nome,target_nome,df, ascending=True):
    agrupado_por_cluster = df.groupby(cluster_nome)[target_nome].mean().reset_index()
    agrupado_por_cluster_ordenado = agrupado_por_cluster.sort_values(by=target_nome,ascending=ascending).reset_index(drop=True)
    agrupado_por_cluster_ordenado['index'] = agrupado_por_cluster_ordenado.index
    juntando_cluster = pd.merge(df,agrupado_por_cluster_ordenado[[cluster_nome,'index']],on=cluster_nome)
    removendo_dandos = juntando_cluster.drop([cluster_nome],axis=1)
    df_final = removendo_dandos.rename(columns={'index':cluster_nome})
    return df_final

# %%
df_usuario = ordenador_cluster('RecenciaCluster','Recencia',df_usuario, ascending=False)

# %%
df_usuario.groupby('RecenciaCluster')['Recencia'].describe()
# Out:
#                    count        mean        std  ...    50%    75%    max
# RecenciaCluster                                  ...
# 0                20697.0  489.070832  59.862148  ...  480.0  532.0  728.0
# 1                30695.0  318.687376  43.450070  ...  312.0  355.0  403.0
# 2                33601.0  187.076277  35.024122  ...  187.0  217.0  252.0
# 3                31588.0   66.405850  35.800016  ...   67.0   99.0  126.0
#
# [4 rows x 8 columns]

# %% [markdown]
# #Clusterizando a Frequência

# %%
df_frequencia = df.groupby('id_unico_cliente').pedido_aprovado.count().reset_index()
df_frequencia.columns = ['id_unico_cliente','Frequencia']
df_frequencia.head()
# Out:
#                    id_unico_cliente  Frequencia
# 0  0000366f3b9a7992bf8c76cfdf3221e2           1
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f           1
# 2  0000f46a3911fa3c0805444483337064           1
# 3  0000f6ccb0745a6a4b88665a16c9f078           1
# 4  0004aac84e0df4da2b147fca70cf8255           1

# %%
df_usuario = pd.merge(df_usuario, df_frequencia,on='id_unico_cliente')
df_usuario.head()
# Out:
#                    id_unico_cliente  ... Frequencia
# 0  861eff4711a542e4b93843c6dd7febb0  ...          1
# 1  3c799d181c34d51f6d44bbbc563024db  ...          1
# 2  567ab47ca4deb92d46dbf54dce07d0a7  ...          1
# 3  f40ab89b622248b7ca125af4b486b887  ...          1
# 4  749943913a9851a39c9baf51877fbab6  ...          1
#
# [5 rows x 8 columns]

# %%
df_frequencia = df_usuario[['Frequencia']]
kmeans = KMeans(n_clusters=4)
df_usuario['FrequenciaCluster'] = kmeans.fit_predict(df_frequencia)
df_usuario.head()
# Out:
#                    id_unico_cliente  ... FrequenciaCluster
# 0  861eff4711a542e4b93843c6dd7febb0  ...                 0
# 1  3c799d181c34d51f6d44bbbc563024db  ...                 0
# 2  567ab47ca4deb92d46dbf54dce07d0a7  ...                 0
# 3  f40ab89b622248b7ca125af4b486b887  ...                 0
# 4  749943913a9851a39c9baf51877fbab6  ...                 0
#
# [5 rows x 9 columns]

# %%
df_usuario.groupby('FrequenciaCluster')['Frequencia'].describe()
# Out:
#                       count       mean       std   min   25%   50%   75%   max
# FrequenciaCluster
# 0                  110394.0   1.399650  0.746239   0.0   1.0   1.0   2.0   4.0
# 1                    5598.0   7.110397  2.561719   5.0   5.0   6.0   8.0  15.0
# 2                      75.0  75.000000  0.000000  75.0  75.0  75.0  75.0  75.0
# 3                     514.0  24.447471  5.669776  16.0  20.0  24.0  24.0  38.0

# %%
df_usuario = ordenador_cluster('FrequenciaCluster','Frequencia',df_usuario, ascending = True) #Na funçao tem que estar ascending = True

# %%
df_usuario.groupby('FrequenciaCluster')['Frequencia'].describe()
# Out:
#                       count       mean       std   min   25%   50%   75%   max
# FrequenciaCluster
# 0                  110394.0   1.399650  0.746239   0.0   1.0   1.0   2.0   4.0
# 1                    5598.0   7.110397  2.561719   5.0   5.0   6.0   8.0  15.0
# 2                     514.0  24.447471  5.669776  16.0  20.0  24.0  24.0  38.0
# 3                      75.0  75.000000  0.000000  75.0  75.0  75.0  75.0  75.0

# %% [markdown]
# #Clusterizando para Receita

# %%
df_receita = df.groupby('id_unico_cliente').pagamento_valor.sum().reset_index()
df_receita.columns = ['id_unico_cliente','Receita']
df_usuario = pd.merge(df_usuario, df_receita, on='id_unico_cliente')
df_usuario.head()
# Out:
#                    id_unico_cliente  ... Receita
# 0  861eff4711a542e4b93843c6dd7febb0  ...  146.87
# 1  3c799d181c34d51f6d44bbbc563024db  ...  140.61
# 2  567ab47ca4deb92d46dbf54dce07d0a7  ...  142.05
# 3  f40ab89b622248b7ca125af4b486b887  ...  155.70
# 4  749943913a9851a39c9baf51877fbab6  ...  148.33
#
# [5 rows x 10 columns]

# %%
df_pagamento = df_usuario[['Receita']]
df_pagamento.head()
# Out:
#    Receita
# 0   146.87
# 1   140.61
# 2   142.05
# 3   155.70
# 4   148.33

# %%
kmeans = KMeans(n_clusters=4)
df_usuario['ReceitaCluster'] = kmeans.fit_predict(df_pagamento)

# %%
df_usuario = ordenador_cluster('ReceitaCluster','Receita', df_usuario, ascending = True)

# %%
df_usuario.groupby('ReceitaCluster')['Receita'].describe()
# Out:
#                    count           mean  ...        75%        max
# ReceitaCluster                           ...
# 0               114763.0     258.095126  ...     269.10    2950.16
# 1                 1619.0    5650.053385  ...    6914.63   16313.60
# 2                  191.0   27358.656911  ...   30186.00   45256.00
# 3                    8.0  109312.640000  ...  109312.64  109312.64
#
# [4 rows x 8 columns]

# %%
df_usuario.head()
# Out:
#                    id_unico_cliente  ... ReceitaCluster
# 0  861eff4711a542e4b93843c6dd7febb0  ...              0
# 1  3c799d181c34d51f6d44bbbc563024db  ...              0
# 2  567ab47ca4deb92d46dbf54dce07d0a7  ...              0
# 3  f40ab89b622248b7ca125af4b486b887  ...              0
# 4  749943913a9851a39c9baf51877fbab6  ...              0
#
# [5 rows x 11 columns]

# %% [markdown]
# #Selecionando colunas

# %%
df_final = df_usuario[['id_unico_cliente','Recencia','RecenciaCluster','Frequencia','FrequenciaCluster','Receita','ReceitaCluster']]
df_final.tail()
# Out:
#                         id_unico_cliente  Recencia  ...    Receita  ReceitaCluster
# 116576  0a0a92112bd4c708ca5fde585afaa872       338  ...  109312.64               3
# 116577  0a0a92112bd4c708ca5fde585afaa872       338  ...  109312.64               3
# 116578  0a0a92112bd4c708ca5fde585afaa872       338  ...  109312.64               3
# 116579  0a0a92112bd4c708ca5fde585afaa872       338  ...  109312.64               3
# 116580  0a0a92112bd4c708ca5fde585afaa872       338  ...  109312.64               3
#
# [5 rows x 7 columns]

# %% [markdown]
# > Calcularemos a pontuação geral do cliente baseado nesses clusters e também definimos 4 opções: inativo, business, master e premium.

# %%
df_final['Pontuacao'] = df_usuario['RecenciaCluster'] + df_usuario['FrequenciaCluster'] + df_usuario['ReceitaCluster']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_final.head()
# Out:
#                    id_unico_cliente  Recencia  ...  ReceitaCluster  Pontuacao
# 0  861eff4711a542e4b93843c6dd7febb0       474  ...               0          0
# 1  3c799d181c34d51f6d44bbbc563024db       483  ...               0          0
# 2  567ab47ca4deb92d46dbf54dce07d0a7       528  ...               0          0
# 3  f40ab89b622248b7ca125af4b486b887       474  ...               0          0
# 4  749943913a9851a39c9baf51877fbab6       533  ...               0          0
#
# [5 rows x 8 columns]

# %%
df_final['Pontuacao'].min(), df_final['Pontuacao'].max()
# Out:
# (0, 7)

# %%
df_final['Segmento'] = 'Inativo'
df_final.loc[df_final['Pontuacao']>=1,'Segmento'] = 'Business'
df_final.loc[df_final['Pontuacao']>=3,'Segmento'] = 'Master'
df_final.loc[df_final['Pontuacao']>=5,'Segmento'] = 'Premium'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
def plot_segmento(x,y,data):
    sns.set(palette='muted',color_codes=True,style='whitegrid')
    plt.figure(figsize=(7,5))
    sns.scatterplot(x=x,y=y,hue='Segmento',data=data,size='Segmento',sizes=(50,150),size_order=['Premium','Master','Business','Inativo'])
    plt.show()

# %%
plot_segmento('Recencia','Frequencia',df_final)

# %%
plot_segmento('Frequencia','Receita',df_final)

# %%
plot_segmento('Recencia','Receita',df_final)

# %%
sns.countplot(df_final['Segmento']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Para fazer uma análise mais completa, poderíamos criar uma tabela inteira se nos basearmos em uma pontuação de 1 a 5 como o exemplo abaixo:

# %% [markdown]
# | **Segmentos**        | **Descrição**                                                      | **Recência** | **Frequência** | **Receita** |
# |----------------------|--------------------------------------------------------------------|--------------|----------------|-------------|
# | Campeões             | Compraram recentemente, compram com frequência e gastam muito      | 4-5          | 4-5            | 4-5         |
# | Clientes fiéis       | Gastam muito e respondem a promoções                               | 2-5          | 3-5            | 3-5         |
# | Potencialmente fiéis | Compraram recentemente, mais de uma vez e gastaram uma boa quantia | 3-5          | 1-3            | 1-3         |
# | Novos clientes       | Compraram recentemente, mas não compram com frequência             | 4-5          | <=1            | <=1         |
# | Promissores          | Compraram recentemente, mas não gastaram muito                     | 3-4          | <=1            | <=1         |
# | Precisam de atenção  | Recência, frequência e valor monetário acima da média              | 2-3          | 2-3            | 2-3         |
# | Quase em risco       | Recência, frequência e valor monetário abaixo da média             | 2-3          | <=2            | <=2         |
# | De risco             | Gastaram muito, compraram muitas vezes, mas há muito tempo         | <=2          | 2-5            | 2-5         |
# | Não pode perdê-los   | Compraram muito e com frequência, mas há muito tempo               | <=1          | 4-5            | 4-5         |
# | Hibernando           | Compraram pouco, com baixa frequência e há muito tempo             | 1-2          | 1-2            | 1-2         |
# | Perdidos             | Recência, frequência e valores monetários baixos                   | <=2          | <=2            | <=2         |
